# %% [markdown]
# Dictionaries: Mappping Services and Ports

# %%
port_dictionary = {
    80 : 'http',
    443: 'https',
    22 : 'ssh'
}

# %%
while True:
    try:
        user_port = int(input("Enter a port number: "))
        break
    except ValueError:
        print("Please enter a valid port number!")

# %%
service_name = port_dictionary.get(user_port)

# %%
if service_name:
    print(f"Port {user_port} uses {service_name.upper()}")
else:
    print(f"No service found for port {user_port}")

# %%
dog = {}

# %%
dog['name'] = 'jack'
dog['color'] = 'white'
dog['breed'] = 'labrador'
dog['legs'] = 4
dog['age'] = 7
dog
# Out:
# {'name': 'jack', 'color': 'white', 'breed': 'labrador', 'legs': 4, 'age': 7}

# %%
student = {'first_name':'Naruto', 'last_name':'Uzumaki', 'gender':'Male', 'age':'18', 'marital_status':'Married', 'skills':['Shadow Clone', 'Rasengan', 'Summoning Jutsu', 'Nature Transformation'], 'country':'Japan', 'city':'Konoha', 'address':' 149-1291, Miyanosawa 4-jo, Nishi-ku, Sapporo-shi, Hokkaido'}

# %%
len(student)
# Out:
# 9

# %%
print(student.get('skills'))
print(type(student['skills']))
# Out:
# ['Shadow Clone', 'Rasengan', 'Summoning Jutsu', 'Nature Transformation', 'Sage Mode']
# <class 'list'>

# %%
student['skills'].append('Sage Mode')
student['skills'].append('Six Paths Sage Mode')
print(student.get('skills'))
# Out:
# ['Shadow Clone', 'Rasengan', 'Summoning Jutsu', 'Nature Transformation', 'Sage Mode', 'Sage Mode', 'Sage Mode', 'Six Paths Sage Mode']

# %%
print(student.keys())
# Out:
# dict_keys(['first_name', 'last_name', 'gender', 'age', 'marital_status', 'skills', 'country', 'city', 'address'])

# %%
print(student.values())
# Out:
# dict_values(['Naruto', 'Uzumaki', 'Male', '18', 'Married', ['Shadow Clone', 'Rasengan', 'Summoning Jutsu', 'Nature Transformation'], 'Japan', 'Konoha', ' 149-1291, Miyanosawa 4-jo, Nishi-ku, Sapporo-shi, Hokkaido'])

# %%
print(student.items())
# Out:
# dict_items([('first_name', 'Naruto'), ('last_name', 'Uzumaki'), ('gender', 'Male'), ('age', '18'), ('marital_status', 'Married'), ('skills', ['Shadow Clone', 'Rasengan', 'Summoning Jutsu', 'Nature Transformation']), ('country', 'Japan'), ('city', 'Konoha'), ('address', ' 149-1291, Miyanosawa 4-jo, Nishi-ku, Sapporo-shi, Hokkaido')])

# %%
student.pop('age')
student
# Out:
# {'first_name': 'Naruto',
#  'last_name': 'Uzumaki',
#  'gender': 'Male',
#  'marital_status': 'Married',
#  'skills': ['Shadow Clone',
#   'Rasengan',
#   'Summoning Jutsu',
#   'Nature Transformation'],
#  'country': 'Japan',
#  'city': 'Konoha',
#  'address': ' 149-1291, Miyanosawa 4-jo, Nishi-ku, Sapporo-shi, Hokkaido'}

# %%
del dog
