# %% [markdown]
# Exception Handling: Building Resilient Scripts and Package managing(PIP).

# %%
import requests 
import re

url = 'https://www.gutenberg.org/cache/epub/1513/pg1513.txt'
response = requests.get(url)
print(response)

text = response.text
lower_text = text.lower()
pattern = r"\b\w+\b"
words = re.findall(pattern, lower_text)

word_counts = {}
for word in words:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

sorted_words = sorted(word_counts.items(), key=lambda item: item[1], reverse=True)
final_result = [(count, word) for word, count in sorted_words]
print(final_result[:10])
# Out:
# <Response [200]>
# [(877, 'the'), (807, 'and'), (659, 'i'), (626, 'to'), (547, 'a'), (518, 'of'), (394, 'in'), (372, 'is'), (369, 'that'), (368, 'you')]

# %%
cat_api = 'https://api.thecatapi.com/v1/breeds'
response = requests.get(cat_api)
cats = response.json()
# print(type(cats))
# print(len(cats))
w = cats[0]["weight"]["metric"]
print(w)
nums = w.split('-')
print(nums)
n1 = int(nums[0])
n2 = int(nums[1])
avg = (n1+n2)/2.0
print(avg)
weights = []
# Out:
# 3 - 5
# ['3 ', ' 5']
# 4.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 16
#      14 weights = []
#      15 for cat_weight in cats:
# ---> 16     print(cat_weight[1])
#
# KeyError: 1
