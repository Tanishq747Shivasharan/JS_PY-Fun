# %% [markdown]
# Functions: Reusable Security Tools

# %%
def validate_ip(ip):
    parts = ip.split(".")
    if len(parts) == 4:
        return True
    else:
        return False

# %%
ip = input("Enter any IPv4 address: ")
print(validate_ip(ip))

# %%
def add_two_numbers(firstnum, secondnum):
    sum = firstnum + secondnum
    return sum
print("The sum of two numbers is: ",add_two_numbers(5, 7))
# Out:
# The sum of two numbers is:  12

# %%
def area_of_circle(r):
    area = 3.14 * r * r
    return area

print("The area of circle is: ",area_of_circle(float(input("Enter radius of circle: "))))
# Out:
# Enter radius of circle:  7
# The area of circle is:  153.86

# %%
def add_all_nums(*args):
    total = 0
    for i in args:
        if type(i)==int or type(i)==float:    # OR isinstance(i, (int, float))
            total += i 
        else:
            print("Please enter valid numbers!")
            return
    return total
            
print(add_all_nums(2, 3,"hello", 4))
# Out:
# Please enter valid numbers!
# None

# %%
def convert_celsius_to_fahrenheit(c):
    F = (c * 9/5) + 32
    return F

print("C converted to F :",convert_celsius_to_fahrenheit(float(input("Enter degree celsius: "))))
# Out:
# Enter degree celsius:  2
# C converted to F : 35.6

# %%
def check_season(month):
    if month == "December" or month=="January" or month=="February":
        return "Winter"
    elif month=="March" or month=="April" or month=="May":
        return "Spring"
    elif month=="June" or month=="July" or month=="August":
        return "Summer"
    elif month=="September" or month=="October" or month=="November":
        return "Autumn"
    else:
        return "invalid"

print("The season is: ",check_season(input("Enter a month: ")))
# Out:
# Enter a month:  November
# The season is:  Autumn

# %%
def calculate_slope(x1,y1,x2,y2):
    m = 0
    m1 = y2-y1
    m2 = x2 - x1
    if m2 == 0:
        print("Cannot divide by zero please enter appropriate values!")
    else:
        m = (y2-y1)/(x2-x1)    # Slope formula
    return m

print(calculate_slope(5, 2, 5, 10))
# Out:
# Cannot divide by zero please enter appropriate values!
# 0

# %%
def print_list(lst):
    for i in lst:
        print(i)

crazy = ['Aditya', 'Yash', 'Dhairyashil']
print_list(crazy)
# Out:
# Aditya
# Yash
# Dhairyashil

# %%
def reverse_list(arr):
    reversed_arr = []

    for i in range(len(arr) - 1, -1, -1):
        reversed_arr.append(arr[i])

    return reversed_arr

print(reverse_list([1, 2, 3, 4, 5]))
print(reverse_list(["A", "B", "C"]))
# Out:
# [5, 4, 3, 2, 1]
# ['C', 'B', 'A']

# %%
def capitalize_list_items(lst):
    for i in lst:
        print(i.capitalize())

lst_a = ['apple', 'mango', 'tanishq', 'Anuja']
capitalize_list_items(lst_a)
# Out:
# Apple
# Mango
# Tanishq
# Anuja

# %%
def add_item(lst, arg):
    lst.append(arg)
    print(lst)

food_stuff = ['Potato', 'Tomato', 'Mango', 'Milk'];
add_item(food_stuff, 'Meat')

numbers = [2, 3, 7, 9];
add_item(numbers, 5)
# Out:
# ['Potato', 'Tomato', 'Mango', 'Milk', 'Meat']
# [2, 3, 7, 9, 5]
